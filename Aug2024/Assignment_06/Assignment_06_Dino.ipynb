# %% [markdown]
# # Assignment_06: Dino
#
# Train DinoV2 on Human Action Recognition
#
# * Same train/test split
# * Use ViT-S: Token Based Transformer
# * 8 patches
#
# Evaluation
#
# * Test Set Classification (Linear)
# * Speed: Turn OFF Flash Attention vs ON (both training and test speed)

# %% [markdown]
# ## What is Dino V2?

# %%
# Import Packages and other things

# %%
# Load Model with Flash Attention

# %%
# Load Data

# %%
# Train and Evaluate

# %%
# Clear GPU Data

# %%
# Load Model without Flash Attention

# %%
# Train and Evaluate
